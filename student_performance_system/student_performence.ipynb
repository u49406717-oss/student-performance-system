# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import sklearn 
import joblib 
import re

# %%
df = pd.read_csv('student_habits_performance.csv')
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   object
# ...

# %%
df.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
df.isnull().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['exam_score'].value_counts()
# Out:
# 100.0    48
# 80.9      7
# 74.0      7
# 70.7      7
# 65.6      7
#          ..
# 60.2      1
# 94.6      1
# 93.4      1
# 71.7      1
# 66.2      1
# Name: exam_score, Length: 480, dtype: int64

# %%
df.shape
# Out:
# (1000, 16)

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
categorical_cols = ['gender','student_id',  'part_time_job','diet_quality','parental_education_level','internet_quality','extracurricular_participation']

# %%
for col in categorical_cols:
    print(f"Values counts for {col}:\n {df[col].value_counts()}")
# Out:
# Values counts for gender:
#  Female    481
# Male      477
# Other      42
# Name: gender, dtype: int64
# Values counts for student_id:
#  S1000    1
# S1671    1
# S1658    1
# S1659    1
# S1660    1
#         ..
# S1338    1
# S1339    1
# S1340    1
# S1341    1
# S1999    1
# Name: student_id, Length: 1000, dtype: int64
# Values counts for part_time_job:
#  No     785
# Yes    215
# Name: part_time_job, dtype: int64
# Values counts for diet_quality:
#  Fair    437
# Good    378
# Poor    185
# Name: diet_quality, dtype: int64
# Values counts for parental_education_level:
#  High School    392
# Bachelor       350
# Master         167
# None            91
# Name: parental_education_level, dtype: int64
# Values counts for internet_quality:
#  Good       447
# Average    391
# Poor       162
# Name: internet_quality, dtype: int64
# Values counts for extracurricular_participation:
#  No     682
# Yes    318
# Name: extracurricular_participation, dtype: int64

# %%
df.hist(bins= 20, edgecolor = "black")
plt.tight_layout()
plt.show()

# %%
for col in categorical_cols:
    sns.countplot(data=df, x = col)
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation  = 45)
    plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap = "coolwarm", fmt = '.2f')
plt.title("correlation Matrix ")
plt.show()

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
num_features = [
    'age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating', 'exam_score'
]

# %%
for feature in num_features:
    sns.scatterplot(data=df, x = feature, y = "exam_score")
    plt.title(f"{feature} vs Exam Score ")
    plt.show()

# %%
for col in categorical_cols:
    sns.boxplot(data=df, x = col , y = "exam_score")
    plt.title(f"Exam score by {col}")
    plt.xticks(rotation = 45)
    plt.show()

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn. linear_model import LinearRegression, Ridge
from sklearn. ensemble import RandomForestRegressor
from sklearn. tree import DecisionTreeRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
feature = ['study_hours_per_day', 'attendance_percentage', 'mental_health_rating', 'sleep_hours','part_time_job' ]

# %%
target = "exam_score"

# %%
df_model = df[feature + [target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours part_time_job  exam_score
# 0            8.0            No        56.2
# ...

# %%
le = LabelEncoder()

# %%
df_model['part_time_job'] = le.fit_transform(df_model['part_time_job'])

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours  part_time_job  exam_score
# 0            8.0              0        56.2
# ...

# %%
X = df_model[feature]

# %%
y = df_model[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2 , )

# %%
len(y_test)
# Out:
# 200

# %%
len(y_train)
# Out:
# 800

# %%
models = {
    "LinearRegression ":{
        "model" : LinearRegression(),
        "params":{}
    },
    "DecisionTree":{
        "model": DecisionTreeRegressor(),
        "params": {"max_depth":[3,5,10], "min_samples_split":[2,5]}
    },
        "RandomForest":{
        "model" : RandomForestRegressor(),
        'params':  {"n_estimators" :[50, 100],"max_depth":[5,10] } 
        }
    }

# %%
best_model = []

# %%
for name, config in models.items():
    print(f"Training {name}")

    grid  = GridSearchCV(config['model'], config['params'], cv = 5, scoring ="neg_mean_squared_error" )
    grid.fit(X_train, y_train)

    y_pred = grid.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    best_model.append({
        "model":name, 
        "best_params":grid.best_params_,
        "rmse":rmse,
        "r2":r2
    })
# Out:
# Training LinearRegression
# Training DecisionTree
# Training RandomForest

# %%
result_df = pd.DataFrame(best_model)

# %%
result_df
# Out:
#                model                               best_params      rmse  \
# 0  LinearRegression                                         {}  7.803841
# 1       DecisionTree  {'max_depth': 5, 'min_samples_split': 5}  9.170876
# 2       RandomForest     {'max_depth': 5, 'n_estimators': 100}  8.145599
#
#          r2
# 0  0.809525
# 1  0.736947
# 2  0.792476

# %%
import joblib 

best_row = result_df.sort_values(by = "rmse").iloc[0]

# %%
best_row
# Out:
# model          LinearRegression
# best_params                   {}
# rmse                    7.803841
# r2                      0.809525
# Name: 0, dtype: object

# %%
best_model_name = best_row["model"]

# %%
best_model_name
# Out:
# 'LinearRegression '

# %%
best_model_config = models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model = best_model_config["model"]

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
joblib.dump(final_model, "best_model.pkl")
# Out:
# ['best_model.pkl']

# %%
joblib.load("best_model.pkl").predict(X_test)
# Out:
# array([ 74.73742636,  81.76483751,  71.12129721,  41.21142058,
#         92.46139347, 102.08438642,  69.95020851,  79.01467611,
#         57.40954206,  63.11370302,  76.23112327,  65.78186195,
#         49.02255865,  79.62809913,  54.13158408,  67.20519009,
#         70.38981885,  48.29971457,  64.30679639,  67.38992181,
#         73.52895166,  67.30619872,  55.24757347,  81.41306008,
#         82.41583073,  92.61586435,  57.83940883,  52.99750849,
#         74.50676277,  50.6197457 ,  78.88292512,  54.85423667,
#         61.13035985,  47.70259344,  71.73131904,  71.70531475,
#         43.9668111 ,  84.6151256 ,  69.49748243,  97.48941383,
#         57.96951467,  87.01739908,  33.25432249,  66.05911303,
#         82.55942489,  64.16899432,  44.8449222 ,  74.22781896,
#         47.31799312,  40.62003739,  71.18087996,  76.26925018,
#         73.50889376,  62.95087154,  55.73271863,  86.13769239,
#         62.14964276,  63.55094645,  89.60531782,  84.74470001,
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, classification_report

# 1. Convert the continuous target 'exam_score' into a Binary Classification target (Pass/Fail)
# We define 50.0 as the passing score
passing_threshold = 50.0
df_model['pass_fail'] = (df_model['exam_score'] >= passing_threshold).astype(int)

# 2. Set up our features and new classification target
X_cls = df_model[feature]
y_cls = df_model['pass_fail']

# 3. Split the data into Train and Test sets
X_train_c, X_test_c, y_train_c, y_test_c = train_test_split(X_cls, y_cls, test_size=0.2, random_state=42)

# 4. Train a Random Forest Classifier
print("Training Classification Model (Random Forest)...")
clf = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)
clf.fit(X_train_c, y_train_c)
y_pred_c = clf.predict(X_test_c)
print("✅ Classification Model Trained Successfully!\n")

# 5. Compute Metrics: Accuracy & Precision
accuracy = accuracy_score(y_test_c, y_pred_c)
precision = precision_score(y_test_c, y_pred_c)

print(f"📊 Accuracy Score:  {accuracy * 100:.2f}%")
print(f"🎯 Precision Score: {precision * 100:.2f}%")
print("\n📝 Complete Classification Report:")
print(classification_report(y_test_c, y_pred_c, target_names=["Fail (Score < 50)", "Pass (Score >= 50)"]))

# 6. Generate and Plot a Beautiful Confusion Matrix Heatmap
cm = confusion_matrix(y_test_c, y_pred_c)

plt.figure(figsize=(6, 5))
sns.heatmap(
    cm, 
    annot=True, 
    fmt="d", 
    cmap="Blues", 
    xticklabels=["Predicted Fail", "Predicted Pass"],
    yticklabels=["Actual Fail", "Actual Pass"],
    cbar=False,
    annot_kws={"size": 14, "weight": "bold"}
)
plt.title("🎓 Student Performance Confusion Matrix", fontsize=14, weight="bold", pad=15)
plt.ylabel("Actual Label", fontsize=12)
plt.xlabel("Predicted Label", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Training Classification Model (Random Forest)...
# ✅ Classification Model Trained Successfully!
#
# 📊 Accuracy Score:  91.00%
# 🎯 Precision Score: 92.31%
#
# 📝 Complete Classification Report:
#                     precision    recall  f1-score   support
#
#  Fail (Score < 50)       0.78      0.50      0.61        28
# Pass (Score >= 50)       0.92      0.98      0.95       172
#
#           accuracy                           0.91       200
#          macro avg       0.85      0.74      0.78       200
#       weighted avg       0.90      0.91      0.90       200
